# %% [markdown]
# Aman Kharwal'ın "Mobile Price Classification with Machine Learning" başlıklı makalesi, Python kullanarak mobil telefonların fiyat aralıklarını sınıflandırmaya yönelik bir makine öğrenimi projesini detaylandırmaktadır. Bu proje, özellikle yeni bir mobil telefon markası kurmak isteyen girişimciler için, cihaz özelliklerine göre fiyat aralığı tahmini yaparak pazarlama ve üretim maliyetlerini karşılayacak uygun fiyatlandırma stratejileri geliştirmeyi amaçlamaktadır.
#
# Projenin Amacı
# Projenin temel amacı, mobil telefonların tam fiyatlarını tahmin etmek yerine, onları dört farklı fiyat aralığına sınıflandırmaktır:
#
# 0 – Düşük maliyetli
#
# 1 – Orta maliyetli
#
# 2 – Yüksek maliyetli
#
# 3 – Çok yüksek maliyetli
# AmanXai
# +3
# Medium
# +3
# Samsung it
# +3
#
# Bu yaklaşım, özellikle pazarlama ve üretim stratejileri belirlerken daha genelleştirilmiş ve uygulanabilir bir çözüm sunar.

# %% [markdown]
# ## Projenin Amacı

# %% [markdown]
# Projenin temel amacı, mobil telefonların tam fiyatlarını tahmin etmek yerine, onları dört farklı fiyat aralığına sınıflandırmaktır:
#
# 0 – Düşük maliyetli
#
# 1 – Orta maliyetli
#
# 2 – Yüksek maliyetli
#
# 3 – Çok yüksek maliyetli
# AmanXai
# +3
# Medium
# +3
# Samsung it
# +3
#
# Bu yaklaşım, özellikle pazarlama ve üretim stratejileri belirlerken daha genelleştirilmiş ve uygulanabilir bir çözüm sunar.

# %% [markdown]
# ##  Kullanılan Veri Seti

# %% [markdown]
# Kullanılan Veri Seti
# Proje, Kaggle'dan alınan ve 21 sütun içeren bir veri seti kullanmaktadır. Bu sütunlar arasında batarya gücü, RAM, ekran boyutu, kamera özellikleri, 4G/3G desteği, Wi-Fi ve dokunmatik ekran gibi teknik özellikler bulunmaktadır. Veri setinde eksik değer bulunmaması, veri ön işleme sürecini kolaylaştırmaktadır.

# %% [markdown]
# ## Veri Ön İşleme

# %% [markdown]
# Tüm özellikler sayısal olduğundan, kategorik veri dönüşümüne gerek duyulmamıştır. Ancak, modelin daha iyi performans göstermesi için veriler standartlaştırılmış ve veri seti %80 eğitim, %20 test olarak bölünmüştür.

# %% [markdown]
# ## Model Eğitimi ve Değerlendirme

# %% [markdown]
# Proje kapsamında, Scikit-learn kütüphanesinin Logistic Regression algoritması kullanılarak model eğitilmiştir. Eğitim sonucunda model, test verileri üzerinde yaklaşık %95.5 doğruluk oranı elde etmiştir.
# AmanXai
#
# Modelin tahmin ettiği fiyat aralıklarının dağılımı şu şekildedir:
#
# Düşük maliyetli (0): 95 adet
#
# Orta maliyetli (1): 90 adet
#
# Yüksek maliyetli (2): 97 adet
#
# Çok yüksek maliyetli (3): 118 adet

# %% [markdown]
# ### Sonuç

# %% [markdown]
# Bu proje, makine öğrenimi tekniklerinin mobil telefon fiyatlandırma stratejilerinde nasıl kullanılabileceğini göstermektedir. Özellikle yeni bir mobil telefon markası kurmayı planlayan girişimciler için, cihaz özelliklerine göre fiyat aralığı tahmini yaparak pazarlama ve üretim maliyetlerini karşılayacak uygun fiyatlandırma stratejileri geliştirmelerine yardımcı olabilir.
#
# Daha fazla detay ve kod örnekleri için Aman Kharwal'ın makalesine ![https://amanxai.com/2021/03/05/mobile-price-classification-with-machine-learning/] ulaşabilirsiniz.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
sns.set()

data = pd.read_csv("mobile_prices.csv")
print(data.head())
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm", linecolor='white', linewidths=1)
# Out:
# <Axes: >

# %% [markdown]
# ### Data Preparation

# %%
x = data.iloc[:, :-1].values
y = data.iloc[:, -1].values
x = StandardScaler().fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
lreg = LogisticRegression()
lreg.fit(x_train, y_train)
y_pred = lreg.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred) * 100
print("Accuracy of the Logistic Regression Model: ",accuracy)
# Out:
# Accuracy of the Logistic Regression Model:  95.5

# %%
print(y_pred)
# Out:
# [3 0 2 2 3 0 0 3 3 1 1 3 0 2 3 0 3 2 2 1 0 0 3 1 2 2 3 1 3 1 1 0 2 0 2 3 0
#  0 3 3 3 1 3 3 1 3 0 1 3 1 1 3 0 3 0 2 2 2 0 3 3 1 3 2 1 2 3 2 2 2 3 2 1 0
#  1 3 2 2 1 2 3 3 3 0 0 0 2 1 2 3 1 2 2 1 0 3 3 3 0 3 1 1 3 1 3 2 2 3 2 3 3
#  0 0 1 3 3 0 0 1 0 0 3 2 2 1 2 1 1 0 2 1 3 3 3 3 3 3 2 0 1 1 2 1 3 0 3 0 0
#  2 0 1 1 1 1 3 0 0 3 1 3 2 1 3 1 2 3 3 2 1 0 3 1 2 3 3 0 2 2 3 1 2 1 0 1 2
#  2 2 0 3 3 1 1 0 2 3 0 1 2 2 0 3 3 3 1 2 3 3 3 0 0 0 2 3 3 0 0 1 3 2 3 3 3
#  0 0 2 3 3 1 0 2 0 0 0 3 2 1 2 2 1 1 0 2 3 3 0 0 1 3 3 1 3 0 3 1 1 0 2 3 3
#  2 0 0 1 2 3 2 2 3 2 1 0 3 3 2 1 3 2 2 2 1 0 2 2 1 0 0 2 2 2 3 0 1 3 0 2 2
#  3 0 2 0 1 1 3 0 0 2 3 1 2 0 2 0 3 0 3 3 2 3 1 2 2 1 1 1 0 1 0 3 1 0 3 0 0
#  1 3 0 3 1 1 0 1 3 0 2 1 1 2 1 1 0 2 0 0 3 1 2 3 2 2 0 3 2 2 1 3 2 3 3 3 0
#  2 0 3 0 1 1 2 3 1 3 1 2 0 1 2 3 0 0 1 3 0 3 0 2 2 1 1 0 2 0]

# %%
(unique, counts) = np.unique(y_pred, return_counts=True)
price_range = np.asarray((unique, counts)).T
print(price_range)
# Out:
# [[  0  95]
#  [  1  90]
#  [  2  97]
#  [  3 118]]

# %% [markdown]
# Modelin tahmin ettiği fiyat aralıklarının dağılımı şu şekildedir:
#
# Düşük maliyetli (0): 95 adet
#
# Orta maliyetli (1): 90 adet
#
# Yüksek maliyetli (2): 97 adet
#
# Çok yüksek maliyetli (3): 118 adet
